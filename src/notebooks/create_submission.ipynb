# %%
import pandas as pd
# Out:
# c:\Users\acer\anaconda3\envs\ml\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\acer\anaconda3\envs\ml\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
# c:\Users\acer\anaconda3\envs\ml\lib\site-packages\numpy\.libs\libopenblas64__v0.3.21-gcc_10_3_0.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
sample = pd.read_csv('../../data/dataset/sample_submission.csv')

# %%
sub = pd.DataFrame(columns=sample.columns)

# %%
sub.head()
# Out:
# Empty DataFrame
# Columns: [year, data_type, source_index, destination_index, value]
# Index: []

# %%
NUMBER_OF_DEPOTS = 21 # to be updated according to the found values
NUMBER_OF_REFINERIES = 4 # to be updated according to the found values
depot_indices = [1256]*NUMBER_OF_DEPOTS
refinery_indices = [1465]*NUMBER_OF_REFINERIES

# %%
sample.describe()
# Out:
#                year  source_index  destination_index         value
# count  2.665900e+04  26659.000000       21798.000000  2.663400e+04
# mean   2.094269e+04   1201.005139        1431.280668  8.091910e+01
# std    6.176944e+05    673.214815         643.769178  4.937779e+02
# min    2.018000e+03      0.000000          98.000000  1.350691e-07
# 25%    2.018000e+03    625.000000        1179.000000  6.505126e+00
# 50%    2.019000e+03   1214.000000        1595.000000  1.758204e+01
# 75%    2.019000e+03   1764.000000        1867.000000  5.804346e+01
# max    2.018202e+07   2417.000000        2252.000000  1.673324e+04

# %%
sample.describe(include='O')
# Out:
#                     data_type
# count                   26659
# unique                      5
# top     biomass_demand_supply
# freq                    21646

# %%
df1 = pd.DataFrame(columns=sample.columns)
df1['year'] = [20182019]*NUMBER_OF_DEPOTS
df1['data_type'] = ['depot_location']*NUMBER_OF_DEPOTS
df1['source_index'] = depot_indices

# %%
sub = pd.concat([sub,df1])

# %%
sub
# Out:
#         year       data_type source_index destination_index value
# 0   20182019  depot_location         1256               NaN   NaN
# 1   20182019  depot_location         1256               NaN   NaN
# 2   20182019  depot_location         1256               NaN   NaN
# 3   20182019  depot_location         1256               NaN   NaN
# 4   20182019  depot_location         1256               NaN   NaN
# 5   20182019  depot_location         1256               NaN   NaN
# 6   20182019  depot_location         1256               NaN   NaN
# 7   20182019  depot_location         1256               NaN   NaN
# 8   20182019  depot_location         1256               NaN   NaN
# 9   20182019  depot_location         1256               NaN   NaN
# 10  20182019  depot_location         1256               NaN   NaN
# 11  20182019  depot_location         1256               NaN   NaN
# 12  20182019  depot_location         1256               NaN   NaN
# 13  20182019  depot_location         1256               NaN   NaN
# 14  20182019  depot_location         1256               NaN   NaN
# 15  20182019  depot_location         1256               NaN   NaN
# 16  20182019  depot_location         1256               NaN   NaN
# 17  20182019  depot_location         1256               NaN   NaN
# 18  20182019  depot_location         1256               NaN   NaN
# 19  20182019  depot_location         1256               NaN   NaN
# 20  20182019  depot_location         1256               NaN   NaN

# %%
df1 = pd.DataFrame(columns=sample.columns)
df1['year'] = [20182019]*NUMBER_OF_REFINERIES
df1['data_type'] = ['refinery_location']*NUMBER_OF_REFINERIES
df1['source_index'] = refinery_indices 

sub = pd.concat([sub,df1])

# %%
sub
# Out:
#         year          data_type source_index destination_index value
# 0   20182019     depot_location         1256               NaN   NaN
# 1   20182019     depot_location         1256               NaN   NaN
# 2   20182019     depot_location         1256               NaN   NaN
# 3   20182019     depot_location         1256               NaN   NaN
# 4   20182019     depot_location         1256               NaN   NaN
# 5   20182019     depot_location         1256               NaN   NaN
# 6   20182019     depot_location         1256               NaN   NaN
# 7   20182019     depot_location         1256               NaN   NaN
# 8   20182019     depot_location         1256               NaN   NaN
# 9   20182019     depot_location         1256               NaN   NaN
# 10  20182019     depot_location         1256               NaN   NaN
# 11  20182019     depot_location         1256               NaN   NaN
# 12  20182019     depot_location         1256               NaN   NaN
# 13  20182019     depot_location         1256               NaN   NaN
# 14  20182019     depot_location         1256               NaN   NaN
# 15  20182019     depot_location         1256               NaN   NaN
# 16  20182019     depot_location         1256               NaN   NaN
# 17  20182019     depot_location         1256               NaN   NaN
# 18  20182019     depot_location         1256               NaN   NaN
# 19  20182019     depot_location         1256               NaN   NaN
# 20  20182019     depot_location         1256               NaN   NaN
# 0   20182019  refinery_location         1465               NaN   NaN
# 1   20182019  refinery_location         1465               NaN   NaN
# 2   20182019  refinery_location         1465               NaN   NaN
# 3   20182019  refinery_location         1465               NaN   NaN

# %%
NUMBER_OF_LOCATIONS =2418
forecast_2018 = [None]*NUMBER_OF_LOCATIONS  #from solution
forecast_2019 = [None] *NUMBER_OF_LOCATIONS #from solution

df1 = pd.DataFrame(columns=sample.columns)
df1['year'] = [2018]*NUMBER_OF_LOCATIONS
df1['data_type'] = ['biomass_forecast']*NUMBER_OF_LOCATIONS
df1['source_index'] = [i for i in range(NUMBER_OF_LOCATIONS)]
df1['value'] = forecast_2018

sub = pd.concat([sub,df1])

# %%
sub
# Out:
#           year         data_type source_index destination_index value
# 0     20182019    depot_location         1256               NaN   NaN
# 1     20182019    depot_location         1256               NaN   NaN
# 2     20182019    depot_location         1256               NaN   NaN
# 3     20182019    depot_location         1256               NaN   NaN
# 4     20182019    depot_location         1256               NaN   NaN
# ...        ...               ...          ...               ...   ...
# 2413      2018  biomass_forecast         2413               NaN   NaN
# 2414      2018  biomass_forecast         2414               NaN   NaN
# 2415      2018  biomass_forecast         2415               NaN   NaN
# 2416      2018  biomass_forecast         2416               NaN   NaN
# 2417      2018  biomass_forecast         2417               NaN   NaN
#
# [2443 rows x 5 columns]

# %%
sub
# Out:
#           year         data_type source_index destination_index value
# 0     20182019    depot_location         1256               NaN   NaN
# 1     20182019    depot_location         1256               NaN   NaN
# 2     20182019    depot_location         1256               NaN   NaN
# 3     20182019    depot_location         1256               NaN   NaN
# 4     20182019    depot_location         1256               NaN   NaN
# ...        ...               ...          ...               ...   ...
# 2413      2018  biomass_forecast         2413               NaN   NaN
# 2414      2018  biomass_forecast         2414               NaN   NaN
# 2415      2018  biomass_forecast         2415               NaN   NaN
# 2416      2018  biomass_forecast         2416               NaN   NaN
# 2417      2018  biomass_forecast         2417               NaN   NaN
#
# [2443 rows x 5 columns]

# %%
biomass_source_index = [125]*10
biomass_destination_index = [200]*10
biomass_flow = [4.3]*10
df1 = pd.DataFrame(columns=sample.columns)
df1['year'] = [2018]*len(biomass_source_index)
df1['data_type'] = ['biomass_demand_supply']*len(biomass_source_index)
df1['source_index'] = biomass_source_index
df1['destination_index'] = biomass_destination_index
df1['value'] = biomass_flow

sub = pd.concat([sub,df1])

# %%
sub
# Out:
#         year              data_type source_index destination_index  value
# 0   20182019         depot_location         1256               NaN    NaN
# 1   20182019         depot_location         1256               NaN    NaN
# 2   20182019         depot_location         1256               NaN    NaN
# 3   20182019         depot_location         1256               NaN    NaN
# 4   20182019         depot_location         1256               NaN    NaN
# ..       ...                    ...          ...               ...    ...
# 5       2018  biomass_demand_supply          125               200    4.3
# 6       2018  biomass_demand_supply          125               200    4.3
# 7       2018  biomass_demand_supply          125               200    4.3
# 8       2018  biomass_demand_supply          125               200    4.3
# 9       2018  biomass_demand_supply          125               200    4.3
#
# [2453 rows x 5 columns]

# %%
nine = sample[sample['year'] == 2019]

# %%
eight = sample[sample['year'] == 2018]

# %%
list(nine[nine['data_type'] == 'biomass_demand_supply'].source_index) == list(eight[eight['data_type'] == 'biomass_demand_supply'].source_index)
# Out:
# True

# %%
eight[eight['data_type'] == 'biomass_demand_supply']
# Out:
#        year              data_type  source_index  destination_index      value
# 2443   2018  biomass_demand_supply             0             1775.0   4.662267
# 2444   2018  biomass_demand_supply             1             1271.0   7.852172
# 2445   2018  biomass_demand_supply             1             2088.0   9.313729
# 2446   2018  biomass_demand_supply             1             1808.0   3.229321
# 2447   2018  biomass_demand_supply             1             1322.0  17.519029
# ...     ...                    ...           ...                ...        ...
# 13261  2018  biomass_demand_supply          2413             1947.0   4.789444
# 13262  2018  biomass_demand_supply          2414             1867.0   0.108563
# 13263  2018  biomass_demand_supply          2415              308.0   0.034991
# 13264  2018  biomass_demand_supply          2416              494.0   1.173867
# 13265  2018  biomass_demand_supply          2417               98.0   0.204258
#
# [10823 rows x 5 columns]

# %%
sub
# Out:
#         year              data_type source_index destination_index  value
# 0   20182019         depot_location         1256               NaN    NaN
# 1   20182019         depot_location         1256               NaN    NaN
# 2   20182019         depot_location         1256               NaN    NaN
# 3   20182019         depot_location         1256               NaN    NaN
# 4   20182019         depot_location         1256               NaN    NaN
# ..       ...                    ...          ...               ...    ...
# 5       2018  biomass_demand_supply          125               200    4.3
# 6       2018  biomass_demand_supply          125               200    4.3
# 7       2018  biomass_demand_supply          125               200    4.3
# 8       2018  biomass_demand_supply          125               200    4.3
# 9       2018  biomass_demand_supply          125               200    4.3
#
# [2453 rows x 5 columns]

# %%
sub.reset_index(drop=True, inplace=True)

# %%
sub
# Out:
#           year              data_type source_index destination_index  value
# 0     20182019         depot_location         1256               NaN    NaN
# 1     20182019         depot_location         1256               NaN    NaN
# 2     20182019         depot_location         1256               NaN    NaN
# 3     20182019         depot_location         1256               NaN    NaN
# 4     20182019         depot_location         1256               NaN    NaN
# ...        ...                    ...          ...               ...    ...
# 2448      2018  biomass_demand_supply          125               200    4.3
# 2449      2018  biomass_demand_supply          125               200    4.3
# 2450      2018  biomass_demand_supply          125               200    4.3
# 2451      2018  biomass_demand_supply          125               200    4.3
# 2452      2018  biomass_demand_supply          125               200    4.3
#
# [2453 rows x 5 columns]

# %%
sub.to_csv('../../outputs/submission.csv', index=False)
